# %%
# BERT not frozen
# torch 1.7
# ngrams = [2, 4, 8]
# epochs = 4
# Routing algorithm iterations = 3
# without the last layer of caps
testing=True
tasks=["asc"]
berts=["pt"]
domains=["rest"]
runs=9
# %run eval/eval.ipynb
# Out:
# ('asc', ':', 'pt', 'rest', 'metric', 0, 85.57)
# array([[85.        , 77.46069814],
#        [86.33928571, 79.39283082],
#        [85.35714286, 78.16122101]])
# ('asc', ':', 'pt', 'rest', 'metric', 1, 78.34)
# array([[85.        , 77.46069814],
#        [86.33928571, 79.39283082],
#        [85.35714286, 78.16122101]])
# ('asc', ':', 'pt', 'rest', 'metric', 0, 85.57)
# array([[85.        , 77.46069814],
#        [86.33928571, 79.39283082],
#        [85.35714286, 78.16122101]])
# ('asc', ':', 'pt', 'rest', 'metric', 1, 78.34)
# array([[85.        , 77.46069814],
#        [86.33928571, 79.39283082],
#        [85.35714286, 78.16122101]])
# ('asc', ':', 'pt', 'rest', 'metric', 0, 85.57)
# array([[85.        , 77.46069814],
#        [86.33928571, 79.39283082],
#        [85.35714286, 78.16122101]])
# ('asc', ':', 'pt', 'rest', 'metric', 1, 78.34)
# array([[85.        , 77.46069814],
#        [86.33928571, 79.39283082],
#        [85.35714286, 78.16122101]])
# ...

# %%
# BERT not frozen
# torch 1.5.1 (sumBERT)
# ngrams = [2, 4, 8]
# epochs = 4
# Routing algorithm iterations = 3
# with the last layer of caps
testing=True
tasks=["asc"]
berts=["pt"]
domains=["rest"]
runs=9
# %run eval/eval.ipynb
# Out:
# ('asc', ':', 'pt', 'rest', 'metric', 0, 85.85)
# array([[85.26785714, 77.40335989],
#        [87.05357143, 80.91085775],
#        [86.07142857, 79.04915188],
#        [84.82142857, 77.53917946],
#        [85.26785714, 78.15625074],
#        [85.98214286, 78.64601727],
#        [85.89285714, 78.76307886],
#        [85.89285714, 79.17394355],
#        [86.42857143, 79.73719652]])
# ('asc', ':', 'pt', 'rest', 'metric', 1, 78.82)
# array([[85.26785714, 77.40335989],
#        [87.05357143, 80.91085775],
#        [86.07142857, 79.04915188],
#        [84.82142857, 77.53917946],
#        [85.26785714, 78.15625074],
#        [85.98214286, 78.64601727],
#        [85.89285714, 78.76307886],
#        [85.89285714, 79.17394355],
#        [86.42857143, 79.73719652]])
# ('asc', ':', 'pt', 'rest', 'metric', 0, 85.85)
# array([[85.26785714, 77.40335989],
#        [87.05357143, 80.91085775],
#        [86.07142857, 79.04915188],
#        [84.82142857, 77.53917946],
#        [85.26785714, 78.15625074],
# ...

# %%
# AKDE routing
# BERT frozen
# torch 1.5.1 (sumBERT)
# ngrams = [2, 4, 8]
# epochs = 4
# Routing algorithm iterations = 3
# with the last layer of caps
testing=True
tasks=["asc"]
berts=["pt"]
domains=["rest"]
runs=9
# %run eval/eval.ipynb
# Out:
# ('asc', ':', 'pt', 'rest', 'metric', 0, 77.69)
# array([[77.58928571, 66.6132716 ],
#        [78.125     , 67.04316518],
#        [77.41071429, 65.88834162],
#        [77.58928571, 66.30774637],
#        [77.76785714, 67.3875764 ],
#        [78.21428571, 68.0569491 ],
#        [77.5       , 66.19859879],
#        [77.5       , 66.0938095 ],
#        [77.5       , 66.93223656]])
# ('asc', ':', 'pt', 'rest', 'metric', 1, 66.72)
# array([[77.58928571, 66.6132716 ],
#        [78.125     , 67.04316518],
#        [77.41071429, 65.88834162],
#        [77.58928571, 66.30774637],
#        [77.76785714, 67.3875764 ],
#        [78.21428571, 68.0569491 ],
#        [77.5       , 66.19859879],
#        [77.5       , 66.0938095 ],
#        [77.5       , 66.93223656]])
# ('asc', ':', 'pt', 'rest', 'metric', 0, 77.69)
# array([[77.58928571, 66.6132716 ],
#        [78.125     , 67.04316518],
#        [77.41071429, 65.88834162],
#        [77.58928571, 66.30774637],
#        [77.76785714, 67.3875764 ],
# ...

# %%
# Dynamic routing
# BERT frozen
# torch 1.5.1 (sumBERT)
# ngrams = [2, 4, 8]
# epochs = 4
# Routing algorithm iterations = 3
# with the last layer of caps
testing=True
tasks=["asc"]
berts=["pt"]
domains=["rest"]
runs=9
# %run eval/eval.ipynb
# Out:
# ('asc', ':', 'pt', 'rest', 'metric', 0, 77.59)
# array([[77.58928571, 66.6132716 ]])
# ('asc', ':', 'pt', 'rest', 'metric', 1, 66.61)
# array([[77.58928571, 66.6132716 ]])
# ('asc', ':', 'pt', 'rest', 'metric', 0, 77.59)
# array([[77.58928571, 66.6132716 ]])
# ('asc', ':', 'pt', 'rest', 'metric', 1, 66.61)
# array([[77.58928571, 66.6132716 ]])
# ('asc', ':', 'pt', 'rest', 'metric', 0, 77.59)
# array([[77.58928571, 66.6132716 ]])
# ('asc', ':', 'pt', 'rest', 'metric', 1, 66.61)
# array([[77.58928571, 66.6132716 ]])
# ('asc', ':', 'pt', 'rest', 'metric', 0, 77.59)
# array([[77.58928571, 66.6132716 ]])
# ('asc', ':', 'pt', 'rest', 'metric', 1, 66.61)
# array([[77.58928571, 66.6132716 ]])
# ('asc', ':', 'pt', 'rest', 'metric', 0, 77.59)
# array([[77.58928571, 66.6132716 ]])
# ('asc', ':', 'pt', 'rest', 'metric', 1, 66.61)
# array([[77.58928571, 66.6132716 ]])
# ('asc', ':', 'pt', 'rest', 'metric', 0, 77.59)
# array([[77.58928571, 66.6132716 ]])
# ...

# %%
# KDE routing
# BERT frozen
# torch 1.5.1 (sumBERT)
# ngrams = [2, 4, 8]
# epochs = 4
# Routing algorithm iterations = 3
# with the last layer of caps
testing=True
tasks=["asc"]
berts=["pt"]
domains=["rest"]
runs=9
# %run eval/eval.ipynb
# Out:
# ('asc', ':', 'pt', 'rest', 'metric', 0, 77.59)
# array([[77.58928571, 66.6132716 ]])
# ('asc', ':', 'pt', 'rest', 'metric', 1, 66.61)
# array([[77.58928571, 66.6132716 ]])
# ('asc', ':', 'pt', 'rest', 'metric', 0, 77.59)
# array([[77.58928571, 66.6132716 ]])
# ('asc', ':', 'pt', 'rest', 'metric', 1, 66.61)
# array([[77.58928571, 66.6132716 ]])
# ('asc', ':', 'pt', 'rest', 'metric', 0, 77.59)
# array([[77.58928571, 66.6132716 ]])
# ('asc', ':', 'pt', 'rest', 'metric', 1, 66.61)
# array([[77.58928571, 66.6132716 ]])
# ('asc', ':', 'pt', 'rest', 'metric', 0, 77.59)
# array([[77.58928571, 66.6132716 ]])
# ('asc', ':', 'pt', 'rest', 'metric', 1, 66.61)
# array([[77.58928571, 66.6132716 ]])
# ('asc', ':', 'pt', 'rest', 'metric', 0, 77.59)
# array([[77.58928571, 66.6132716 ]])
# ('asc', ':', 'pt', 'rest', 'metric', 1, 66.61)
# array([[77.58928571, 66.6132716 ]])
# ('asc', ':', 'pt', 'rest', 'metric', 0, 77.59)
# array([[77.58928571, 66.6132716 ]])
# ...

# %%
# Dymanic routing
# torch 1.5.1 (sumBERT)
# ngrams = [2, 4, 8]
# epochs = 4
# Routing algorithm iterations = 3
testing=True
tasks=["asc"]
berts=["pt"]
domains=["rest"]
runs=9
# %run eval/eval.ipynb
# Out:
# asc : pt rest metric 0 79.65
# array([[83.39285714, 75.13579605],
#        [83.125     , 73.99170679],
#        [83.125     , 74.48499213],
#        [76.60714286, 68.63405407],
#        [84.55357143, 75.94993525],
#        [81.78571429, 72.2778635 ],
#        [65.        , 26.26262626],
#        [79.64285714, 70.51509972]])
# asc : pt rest metric 1 67.16
# array([[83.39285714, 75.13579605],
#        [83.125     , 73.99170679],
#        [83.125     , 74.48499213],
#        [76.60714286, 68.63405407],
#        [84.55357143, 75.94993525],
#        [81.78571429, 72.2778635 ],
#        [65.        , 26.26262626],
#        [79.64285714, 70.51509972]])
# asc : pt rest metric 0 79.65
# array([[83.39285714, 75.13579605],
#        [83.125     , 73.99170679],
#        [83.125     , 74.48499213],
#        [76.60714286, 68.63405407],
#        [84.55357143, 75.94993525],
#        [81.78571429, 72.2778635 ],
#        [65.        , 26.26262626],
#        [79.64285714, 70.51509972]])
# ...

# %%
# Dymanic routing
# torch 1.5.1 (sumBERT)
# ngrams = [2, 3, 4]
# epochs = 4
# Routing algorithm iterations = 3
testing=True
tasks=["asc"]
berts=["pt"]
domains=["rest"]
runs=9
# %run eval/eval.ipynb
# Out:
# asc : pt rest metric 0 81.52
# array([[81.51785714, 71.31295196]])
# asc : pt rest metric 1 71.31
# array([[81.51785714, 71.31295196]])
# asc : pt rest metric 0 81.52
# array([[81.51785714, 71.31295196]])
# asc : pt rest metric 1 71.31
# array([[81.51785714, 71.31295196]])
# asc : pt rest metric 0 81.52
# array([[81.51785714, 71.31295196]])
# asc : pt rest metric 1 71.31
# array([[81.51785714, 71.31295196]])
# asc : pt rest metric 0 81.52
# array([[81.51785714, 71.31295196]])
# asc : pt rest metric 1 71.31
# array([[81.51785714, 71.31295196]])
# asc : pt rest metric 0 81.52
# array([[81.51785714, 71.31295196]])
# asc : pt rest metric 1 71.31
# array([[81.51785714, 71.31295196]])
# asc : pt rest metric 0 81.52
# array([[81.51785714, 71.31295196]])
# asc : pt rest metric 1 71.31
# array([[81.51785714, 71.31295196]])
# asc : pt rest metric 0 81.52
# array([[81.51785714, 71.31295196]])
# asc : pt rest metric 1 71.31
# array([[81.51785714, 71.31295196]])
# asc : pt rest metric 0 81.52
# ...

# %%
# Dymanic routing
# torch 1.5.1 (sumBERT)
# ngrams = [2, 3, 4]
# epochs = 10
# Routing algorithm iterations = 3
testing=True
tasks=["asc"]
berts=["pt"]
domains=["rest"]
runs=9
# %run eval/eval.ipynb
# Out:
# asc : pt rest metric 0 83.3
# array([[83.30357143, 75.31426507]])
# asc : pt rest metric 1 75.31
# array([[83.30357143, 75.31426507]])
# asc : pt rest metric 0 83.3
# array([[83.30357143, 75.31426507]])
# asc : pt rest metric 1 75.31
# array([[83.30357143, 75.31426507]])
# asc : pt rest metric 0 83.3
# array([[83.30357143, 75.31426507]])
# asc : pt rest metric 1 75.31
# array([[83.30357143, 75.31426507]])
# asc : pt rest metric 0 83.3
# array([[83.30357143, 75.31426507]])
# asc : pt rest metric 1 75.31
# array([[83.30357143, 75.31426507]])
# asc : pt rest metric 0 83.3
# array([[83.30357143, 75.31426507]])
# asc : pt rest metric 1 75.31
# array([[83.30357143, 75.31426507]])
# asc : pt rest metric 0 83.3
# array([[83.30357143, 75.31426507]])
# asc : pt rest metric 1 75.31
# array([[83.30357143, 75.31426507]])
# asc : pt rest metric 0 83.3
# array([[83.30357143, 75.31426507]])
# asc : pt rest metric 1 75.31
# array([[83.30357143, 75.31426507]])
# asc : pt rest metric 0 83.3
# ...

# %%
# Dymanic routing
# torch 1.5.1 (sumBERT)
# ngrams = [2, 3, 4]
# epochs = 20
# Routing algorithm iterations = 3
testing=True
tasks=["asc"]
berts=["pt"]
domains=["rest"]
runs=9
# %run eval/eval.ipynb
# Out:
# asc : pt rest metric 0 85.54
# array([[85.53571429, 77.9437249 ]])
# asc : pt rest metric 1 77.94
# array([[85.53571429, 77.9437249 ]])
# asc : pt rest metric 0 85.54
# array([[85.53571429, 77.9437249 ]])
# asc : pt rest metric 1 77.94
# array([[85.53571429, 77.9437249 ]])
# asc : pt rest metric 0 85.54
# array([[85.53571429, 77.9437249 ]])
# asc : pt rest metric 1 77.94
# array([[85.53571429, 77.9437249 ]])
# asc : pt rest metric 0 85.54
# array([[85.53571429, 77.9437249 ]])
# asc : pt rest metric 1 77.94
# array([[85.53571429, 77.9437249 ]])
# asc : pt rest metric 0 85.54
# array([[85.53571429, 77.9437249 ]])
# asc : pt rest metric 1 77.94
# array([[85.53571429, 77.9437249 ]])
# asc : pt rest metric 0 85.54
# array([[85.53571429, 77.9437249 ]])
# asc : pt rest metric 1 77.94
# array([[85.53571429, 77.9437249 ]])
# asc : pt rest metric 0 85.54
# array([[85.53571429, 77.9437249 ]])
# asc : pt rest metric 1 77.94
# array([[85.53571429, 77.9437249 ]])
# asc : pt rest metric 0 85.54
# ...

# %%
# Dymanic routing
# frozen BERT
# torch 1.5.1 (sumBERT)
# ngrams = [2, 3, 4]
# epochs = 20
# Routing algorithm iterations = 3
testing=True
tasks=["asc"]
berts=["pt"]
domains=["rest"]
runs=9
# %run eval/eval.ipynb
# Out:
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# ...

# %%
# Dymanic routing
# frozen BERT
# torch 1.5.1 (sumBERT)
# ngrams = [2, 3, 4]
# epochs = 20
# Routing algorithm iterations = 10
testing=True
tasks=["asc"]
berts=["pt"]
domains=["rest"]
runs=9
# %run eval/eval.ipynb
# Out:
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# ...

# %%
# Sabour Dymanic routing
# frozen BERT
# torch 1.5.1 (sumBERT)
# ngrams = [2, 3, 4]
# epochs = 4
# Routing algorithm iterations = 10
testing=True
tasks=["asc"]
berts=["pt"]
domains=["rest"]
runs=9
# %run eval/eval.ipynb
# Out:
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# ...

# %%
# frozen BERT
# torch 1.5.1 (sumBERT)
# ngrams = [2, 3, 4]
# epochs = 4
# with dynamic routing
testing=True
tasks=["asc"]
berts=["pt"]
domains=["rest"]
runs=9
# %run eval/eval.ipynb
# Out:
# asc : pt rest metric 0 75.45
# array([[75.44642857, 65.9194857 ]])
# asc : pt rest metric 1 65.92
# array([[75.44642857, 65.9194857 ]])
# asc : pt rest metric 0 75.45
# array([[75.44642857, 65.9194857 ]])
# asc : pt rest metric 1 65.92
# array([[75.44642857, 65.9194857 ]])
# asc : pt rest metric 0 75.45
# array([[75.44642857, 65.9194857 ]])
# asc : pt rest metric 1 65.92
# array([[75.44642857, 65.9194857 ]])
# asc : pt rest metric 0 75.45
# array([[75.44642857, 65.9194857 ]])
# asc : pt rest metric 1 65.92
# array([[75.44642857, 65.9194857 ]])
# asc : pt rest metric 0 75.45
# array([[75.44642857, 65.9194857 ]])
# asc : pt rest metric 1 65.92
# array([[75.44642857, 65.9194857 ]])
# asc : pt rest metric 0 75.45
# array([[75.44642857, 65.9194857 ]])
# asc : pt rest metric 1 65.92
# array([[75.44642857, 65.9194857 ]])
# asc : pt rest metric 0 75.45
# array([[75.44642857, 65.9194857 ]])
# asc : pt rest metric 1 65.92
# array([[75.44642857, 65.9194857 ]])
# asc : pt rest metric 0 75.45
# ...

# %%
# frozen BERT
# torch 1.5.1 (sumBERT)
# ngrams = [2, 3, 4]
# epochs = 10
# with dynamic routing
testing=True
tasks=["asc"]
berts=["pt"]
domains=["rest"]
runs=9
# %run eval/eval.ipynb
# Out:
# asc : pt rest metric 0 78.04
# array([[78.03571429, 66.26112981]])
# asc : pt rest metric 1 66.26
# array([[78.03571429, 66.26112981]])
# asc : pt rest metric 0 78.04
# array([[78.03571429, 66.26112981]])
# asc : pt rest metric 1 66.26
# array([[78.03571429, 66.26112981]])
# asc : pt rest metric 0 78.04
# array([[78.03571429, 66.26112981]])
# asc : pt rest metric 1 66.26
# array([[78.03571429, 66.26112981]])
# asc : pt rest metric 0 78.04
# array([[78.03571429, 66.26112981]])
# asc : pt rest metric 1 66.26
# array([[78.03571429, 66.26112981]])
# asc : pt rest metric 0 78.04
# array([[78.03571429, 66.26112981]])
# asc : pt rest metric 1 66.26
# array([[78.03571429, 66.26112981]])
# asc : pt rest metric 0 78.04
# array([[78.03571429, 66.26112981]])
# asc : pt rest metric 1 66.26
# array([[78.03571429, 66.26112981]])
# asc : pt rest metric 0 78.04
# array([[78.03571429, 66.26112981]])
# asc : pt rest metric 1 66.26
# array([[78.03571429, 66.26112981]])
# asc : pt rest metric 0 78.04
# ...

# %%
# Sabour Dymanic routing
# frozen BERT
# torch 1.5.1 (sumBERT)
# ngrams = [2, 3, 4]
# epochs = 4
# Routing algorithm iterations = 10
# output dimension: 16
# input dimension: 8
testing=True
tasks=["asc"]
berts=["pt"]
domains=["rest"]
runs=9
# %run eval/eval.ipynb
# Out:
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# array([[65.        , 26.26262626]])
# asc : pt rest metric 1 26.26
# array([[65.        , 26.26262626]])
# asc : pt rest metric 0 65.0
# ...

# %%
testing=True
tasks=["asc"]
berts=["pt"]
domains=["rest"]
runs=9
# %run eval/eval.ipynb
# Out:
# asc : pt rest metric 0 85.05
# array([[84.10714286, 75.84251721],
#        [85.71428571, 78.33491482],
#        [85.26785714, 77.16495178],
#        [84.55357143, 76.38057004],
#        [85.17857143, 77.16056055],
#        [86.78571429, 80.67216472],
#        [83.75      , 75.63260516],
#        [85.08928571, 77.19997648],
#        [85.        , 76.7922798 ]])
# asc : pt rest metric 1 77.24
# array([[84.10714286, 75.84251721],
#        [85.71428571, 78.33491482],
#        [85.26785714, 77.16495178],
#        [84.55357143, 76.38057004],
#        [85.17857143, 77.16056055],
#        [86.78571429, 80.67216472],
#        [83.75      , 75.63260516],
#        [85.08928571, 77.19997648],
#        [85.        , 76.7922798 ]])
# asc : pt rest metric 0 85.05
# array([[84.10714286, 75.84251721],
#        [85.71428571, 78.33491482],
#        [85.26785714, 77.16495178],
#        [84.55357143, 76.38057004],
#        [85.17857143, 77.16056055],
#        [86.78571429, 80.67216472],
# ...

# %%
testing=True
tasks=["asc"]
berts=["pt"]
domains=["rest"]
runs=9
# %run eval/eval.ipynb
# Out:
# asc : pt rest metric 0 78.72
# array([[78.21428571, 66.21876466],
#        [78.75      , 67.79215738],
#        [79.19642857, 67.83391629]])
# asc : pt rest metric 1 67.28
# array([[78.21428571, 66.21876466],
#        [78.75      , 67.79215738],
#        [79.19642857, 67.83391629]])
# asc : pt rest metric 0 78.72
# array([[78.21428571, 66.21876466],
#        [78.75      , 67.79215738],
#        [79.19642857, 67.83391629]])
# asc : pt rest metric 1 67.28
# array([[78.21428571, 66.21876466],
#        [78.75      , 67.79215738],
#        [79.19642857, 67.83391629]])
# asc : pt rest metric 0 78.72
# array([[78.21428571, 66.21876466],
#        [78.75      , 67.79215738],
#        [79.19642857, 67.83391629]])
# asc : pt rest metric 1 67.28
# array([[78.21428571, 66.21876466],
#        [78.75      , 67.79215738],
#        [79.19642857, 67.83391629]])
# asc : pt rest metric 0 78.72
# array([[78.21428571, 66.21876466],
#        [78.75      , 67.79215738],
# ...
